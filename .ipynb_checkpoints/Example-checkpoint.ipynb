# %%
from Finance.Portfolio_optimization_binary import PortfolioOptimization_Binary

# %%
import numpy as np

# %%
#Defining parameters
n = 5  # number of assets

mu = np.array([0.10, 0.12, 0.07, 0.09, 0.11])

Sigma = np.array([
    [0.10, 0.02, 0.01, 0.03, 0.02],
    [0.02, 0.08, 0.02, 0.01, 0.03],
    [0.01, 0.02, 0.09, 0.02, 0.01],
    [0.03, 0.01, 0.02, 0.07, 0.02],
    [0.02, 0.03, 0.01, 0.02, 0.06]
])

K = 3
lam = 1.0
P = 10.0

# %%
#Creating the portfolio optimization problem
PFO_test = PortfolioOptimization_Binary(n= mu.size, mu=mu, Sigma=Sigma, lam=lam)

# %%
# Adding Budget Constraint
PFO_test.add_budget_constraint(P,K)

# %%
Graph = PFO_test.build_graph()

# %%
H_object = PFO_test.build_hamiltonian()
print(H_object)
# Out:
# -4.960000000000001 * Z(0) + -4.98 * Z(1) + -4.959999999999997 * Z(2) + -4.970000000000002 * Z(3) + -4.984999999999999 * Z(4) + 5.005000000000001 * (Z(1) @ Z(3)) + 5.01 * (Z(0) @ Z(1)) + 5.01 * (Z(2) @ Z(3)) + 5.005000000000001 * (Z(0) @ Z(2)) + 5.015000000000001 * (Z(0) @ Z(3)) + 5.01 * (Z(0) @ Z(4)) + 5.01 * (Z(1) @ Z(2)) + 5.015000000000001 * (Z(1) @ Z(4)) + 5.005000000000001 * (Z(2) @ Z(4)) + 5.01 * (Z(3) @ Z(4))

# %%
p=3
Solve_test = PFO_test.solver(p)
# Out:
# Step 0: Energy = 32.04921953457539
# Step 10: Energy = 15.57974394088403
# Step 20: Energy = -0.5364570963873674
# Step 30: Energy = -8.135282737145356
# Step 40: Energy = -10.906287680389621
# Step 50: Energy = -10.999340957137278
# Step 60: Energy = -11.562708133729123
# Step 70: Energy = -11.903607586228718
# Step 80: Energy = -12.313692381410712
# Step 90: Energy = -12.413207230460515

# %%
Solve_test
# Out:
# {'gammas_opt': tensor([ 0.60121592, -0.58030874,  0.28838897], requires_grad=True),
#  'betas_opt': tensor([0.89507896, 0.11962838, 0.55319361], requires_grad=True),
#  'energy': tensor(-12.43847481, requires_grad=True),
#  'history': [tensor(32.04921953, requires_grad=True),
#   tensor(9.52824976, requires_grad=True),
#   tensor(-1.20267125, requires_grad=True),
#   tensor(-5.45990076, requires_grad=True),
#   tensor(13.67426362, requires_grad=True),
#   tensor(29.28603205, requires_grad=True),
#   tensor(18.13454349, requires_grad=True),
#   tensor(-2.03548493, requires_grad=True),
#   tensor(-1.80574593, requires_grad=True),
#   tensor(12.71820983, requires_grad=True),
#   tensor(15.57974394, requires_grad=True),
#   tensor(17.21105247, requires_grad=True),
#   tensor(18.45795916, requires_grad=True),
#   tensor(4.8816641, requires_grad=True),
#   tensor(33.14446073, requires_grad=True),
#   tensor(25.99992375, requires_grad=True),
#   tensor(6.63281492, requires_grad=True),
#   tensor(10.96336622, requires_grad=True),
#   tensor(11.8851656, requires_grad=True),
#   tensor(8.40659777, requires_grad=True),
#   tensor(-0.5364571, requires_grad=True),
#   tensor(-1.88779716, requires_grad=True),
#   tensor(-9.88412618, requires_grad=True),
#   tensor(-5.4220105, requires_grad=True),
#   tensor(-4.25393962, requires_grad=True),
#   tensor(-4.91127117, requires_grad=True),
#   tensor(-8.4035833, requires_grad=True),
#   tensor(-11.11098415, requires_grad=True),
#   tensor(-9.75617051, requires_grad=True),
#   tensor(-7.73502395, requires_grad=True),
#   tensor(-8.13528274, requires_grad=True),
#   tensor(-10.0382564, requires_grad=True),
#   tensor(-10.31028409, requires_grad=True),
#   tensor(-9.14337133, requires_grad=True),
#   tensor(-9.15168024, requires_grad=True),
#   tensor(-10.5520064, requires_grad=True),
#   tensor(-10.97598395, requires_grad=True),
#   tensor(-10.01652613, requires_grad=True),
#   tensor(-9.50701954, requires_grad=True),
#   tensor(-10.2072967, requires_grad=True),
#   tensor(-10.90628768, requires_grad=True),
#   tensor(-10.34081628, requires_grad=True),
#   tensor(-10.13960795, requires_grad=True),
#   tensor(-10.65938129, requires_grad=True),
#   tensor(-11.38628534, requires_grad=True),
#   tensor(-11.3773765, requires_grad=True),
#   tensor(-11.11313982, requires_grad=True),
#   tensor(-11.14757451, requires_grad=True),
#   tensor(-11.2105836, requires_grad=True),
#   tensor(-11.07498651, requires_grad=True),
#   tensor(-10.99934096, requires_grad=True),
#   tensor(-11.12216337, requires_grad=True),
#   tensor(-11.25401337, requires_grad=True),
#   tensor(-11.52638387, requires_grad=True),
#   tensor(-11.70965444, requires_grad=True),
#   tensor(-11.57007191, requires_grad=True),
#   tensor(-11.40473656, requires_grad=True),
#   tensor(-11.46047845, requires_grad=True),
#   tensor(-11.5398578, requires_grad=True),
#   tensor(-11.5163104, requires_grad=True),
#   tensor(-11.56270813, requires_grad=True),
#   tensor(-11.68880824, requires_grad=True),
#   tensor(-11.77749357, requires_grad=True),
#   tensor(-11.81897978, requires_grad=True),
#   tensor(-11.82163744, requires_grad=True),
#   tensor(-11.81030361, requires_grad=True),
#   tensor(-11.80277612, requires_grad=True),
#   tensor(-11.80381704, requires_grad=True),
#   tensor(-11.8125714, requires_grad=True),
#   tensor(-11.84140401, requires_grad=True),
#   tensor(-11.90360759, requires_grad=True),
#   tensor(-11.95334438, requires_grad=True),
#   tensor(-11.96311265, requires_grad=True),
#   tensor(-11.97261276, requires_grad=True),
#   tensor(-12.00688077, requires_grad=True),
#   tensor(-12.03963931, requires_grad=True),
#   tensor(-12.06934869, requires_grad=True),
#   tensor(-12.12411328, requires_grad=True),
#   tensor(-12.19849987, requires_grad=True),
#   tensor(-12.26266287, requires_grad=True),
#   tensor(-12.31369238, requires_grad=True),
#   tensor(-12.35353434, requires_grad=True),
#   tensor(-12.37101376, requires_grad=True),
#   tensor(-12.35729657, requires_grad=True),
#   tensor(-12.3244747, requires_grad=True),
#   tensor(-12.29875352, requires_grad=True),
#   tensor(-12.30131502, requires_grad=True),
#   tensor(-12.32842355, requires_grad=True),
#   tensor(-12.36323183, requires_grad=True),
#   tensor(-12.39382747, requires_grad=True),
#   tensor(-12.41320723, requires_grad=True),
#   tensor(-12.41261841, requires_grad=True),
#   tensor(-12.39629429, requires_grad=True),
#   tensor(-12.3812175, requires_grad=True),
#   tensor(-12.37476827, requires_grad=True),
#   tensor(-12.37811666, requires_grad=True),
#   tensor(-12.39355656, requires_grad=True),
#   tensor(-12.41323371, requires_grad=True),
#   tensor(-12.42832073, requires_grad=True),
#   tensor(-12.43847481, requires_grad=True)],
#  'top_solutions': [('10011', 93),
#   ('11001', 92),
#   ('10110', 90),
#   ('11100', 88),
#   ('00111', 87)],
#  'n_qubits': 5}
