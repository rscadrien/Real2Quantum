# %%
from Finance.Portfolio_optimization_binary import PortfolioOptimization_Binary

# %%
import numpy as np

# %%
#Defining parameters
n = 5  # number of assets

mu = np.array([0.10, 0.12, 0.07, 0.09, 0.11])

Sigma = np.array([
    [0.10, 0.02, 0.01, 0.03, 0.02],
    [0.02, 0.08, 0.02, 0.01, 0.03],
    [0.01, 0.02, 0.09, 0.02, 0.01],
    [0.03, 0.01, 0.02, 0.07, 0.02],
    [0.02, 0.03, 0.01, 0.02, 0.06]
])

K = 3
lam = 1.0
P = 10.0

# %%
#Creating the portfolio optimization problem
PFO_test = PortfolioOptimization_Binary(n= mu.size, mu=mu, Sigma=Sigma, lam=lam)

# %%
# Adding Budget Constraint
PFO_test.add_budget_constraint(P,K)

# %%
Graph = PFO_test.build_graph()

# %%
H_object = PFO_test.build_hamiltonian()
print(H_object)
# Out:
# -4.960000000000001 * Z(0) + -4.98 * Z(1) + -4.959999999999997 * Z(2) + -4.970000000000002 * Z(3) + -4.984999999999999 * Z(4) + 5.005000000000001 * (Z(1) @ Z(3)) + 5.01 * (Z(0) @ Z(1)) + 5.01 * (Z(2) @ Z(3)) + 5.005000000000001 * (Z(0) @ Z(2)) + 5.015000000000001 * (Z(0) @ Z(3)) + 5.01 * (Z(0) @ Z(4)) + 5.01 * (Z(1) @ Z(2)) + 5.015000000000001 * (Z(1) @ Z(4)) + 5.005000000000001 * (Z(2) @ Z(4)) + 5.01 * (Z(3) @ Z(4))

# %%
p=3
Solve_test = PFO_test.solver(p)
# Out:
# Step 0: Energy = 7.2387560782435205
# Step 10: Energy = 9.617859459315364
# Step 20: Energy = -7.006886059887532
# Step 30: Energy = -12.807584171087415
# Step 40: Energy = -12.184957399910726
# Step 50: Energy = -13.11050927359909
# Step 60: Energy = -10.32868672285914
# Step 70: Energy = -12.459657677253135
# Step 80: Energy = -13.646836842063776
# Step 90: Energy = -13.981691071423827

# %%
Solve_test
# Out:
# {'gammas_opt': tensor([0.82801633, 0.87205678, 1.39244451], requires_grad=True),
#  'betas_opt': tensor([ 0.25654682,  0.3261709 , -0.73328739], requires_grad=True),
#  'energy': tensor(-14.20628444, requires_grad=True),
#  'history': [tensor(7.23875608, requires_grad=True),
#   tensor(-0.24305551, requires_grad=True),
#   tensor(19.87919594, requires_grad=True),
#   tensor(-9.12322279, requires_grad=True),
#   tensor(18.69130657, requires_grad=True),
#   tensor(22.98168266, requires_grad=True),
#   tensor(17.45728948, requires_grad=True),
#   tensor(4.93282057, requires_grad=True),
#   tensor(19.46442421, requires_grad=True),
#   tensor(15.16599404, requires_grad=True),
#   tensor(9.61785946, requires_grad=True),
#   tensor(14.49279375, requires_grad=True),
#   tensor(19.62795592, requires_grad=True),
#   tensor(15.79271328, requires_grad=True),
#   tensor(9.62573677, requires_grad=True),
#   tensor(13.75516896, requires_grad=True),
#   tensor(7.99771051, requires_grad=True),
#   tensor(-8.36293257, requires_grad=True),
#   tensor(4.04299361, requires_grad=True),
#   tensor(-1.53930411, requires_grad=True),
#   tensor(-7.00688606, requires_grad=True),
#   tensor(-2.07833907, requires_grad=True),
#   tensor(-9.05704119, requires_grad=True),
#   tensor(-7.43373581, requires_grad=True),
#   tensor(-5.16556389, requires_grad=True),
#   tensor(-4.0289302, requires_grad=True),
#   tensor(-5.13174686, requires_grad=True),
#   tensor(-7.49488336, requires_grad=True),
#   tensor(-9.84685492, requires_grad=True),
#   tensor(-9.93011895, requires_grad=True),
#   tensor(-12.80758417, requires_grad=True),
#   tensor(-9.9613048, requires_grad=True),
#   tensor(-10.04788738, requires_grad=True),
#   tensor(-11.22146306, requires_grad=True),
#   tensor(-11.38273806, requires_grad=True),
#   tensor(-11.7981205, requires_grad=True),
#   tensor(-10.6927859, requires_grad=True),
#   tensor(-11.19418632, requires_grad=True),
#   tensor(-12.21531136, requires_grad=True),
#   tensor(-12.94964241, requires_grad=True),
#   tensor(-12.1849574, requires_grad=True),
#   tensor(-12.64290225, requires_grad=True),
#   tensor(-12.87720977, requires_grad=True),
#   tensor(-13.31292688, requires_grad=True),
#   tensor(-11.80564185, requires_grad=True),
#   tensor(-8.87110642, requires_grad=True),
#   tensor(-6.72264374, requires_grad=True),
#   tensor(-13.06692479, requires_grad=True),
#   tensor(-12.39559278, requires_grad=True),
#   tensor(-9.84814629, requires_grad=True),
#   tensor(-13.11050927, requires_grad=True),
#   tensor(-12.43587583, requires_grad=True),
#   tensor(-10.88766927, requires_grad=True),
#   tensor(-13.38619058, requires_grad=True),
#   tensor(-11.11247575, requires_grad=True),
#   tensor(-10.29707786, requires_grad=True),
#   tensor(-13.60959784, requires_grad=True),
#   tensor(-10.50097541, requires_grad=True),
#   tensor(-11.89269134, requires_grad=True),
#   tensor(-13.44966921, requires_grad=True),
#   tensor(-10.32868672, requires_grad=True),
#   tensor(-12.70537135, requires_grad=True),
#   tensor(-13.18415943, requires_grad=True),
#   tensor(-10.9414167, requires_grad=True),
#   tensor(-12.49302724, requires_grad=True),
#   tensor(-13.97591107, requires_grad=True),
#   tensor(-12.1629314, requires_grad=True),
#   tensor(-12.6678049, requires_grad=True),
#   tensor(-13.91595102, requires_grad=True),
#   tensor(-13.1415324, requires_grad=True),
#   tensor(-12.45965768, requires_grad=True),
#   tensor(-13.94652282, requires_grad=True),
#   tensor(-13.66031973, requires_grad=True),
#   tensor(-12.63634457, requires_grad=True),
#   tensor(-13.66928337, requires_grad=True),
#   tensor(-14.01863754, requires_grad=True),
#   tensor(-13.28368917, requires_grad=True),
#   tensor(-13.48552081, requires_grad=True),
#   tensor(-14.0520894, requires_grad=True),
#   tensor(-13.76772068, requires_grad=True),
#   tensor(-13.64683684, requires_grad=True),
#   tensor(-13.91376352, requires_grad=True),
#   tensor(-14.15704237, requires_grad=True),
#   tensor(-13.9390609, requires_grad=True),
#   tensor(-13.81691216, requires_grad=True),
#   tensor(-13.98146665, requires_grad=True),
#   tensor(-14.17186047, requires_grad=True),
#   tensor(-14.09901056, requires_grad=True),
#   tensor(-13.96003599, requires_grad=True),
#   tensor(-13.88363296, requires_grad=True),
#   tensor(-13.98169107, requires_grad=True),
#   tensor(-14.13081232, requires_grad=True),
#   tensor(-14.17551633, requires_grad=True),
#   tensor(-14.13869192, requires_grad=True),
#   tensor(-14.04517137, requires_grad=True),
#   tensor(-14.03956173, requires_grad=True),
#   tensor(-14.0507667, requires_grad=True),
#   tensor(-14.12645348, requires_grad=True),
#   tensor(-14.1693793, requires_grad=True),
#   tensor(-14.20628444, requires_grad=True)],
#  'top_solutions': [('11010', 110),
#   ('01011', 103),
#   ('10110', 98),
#   ('00111', 97),
#   ('11001', 97)],
#  'n_qubits': 5}
